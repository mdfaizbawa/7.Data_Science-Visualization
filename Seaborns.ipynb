# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Placement.csv')
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#Number of rows and columns
print('no. of row',dataset.shape[0])
print('no. of column',dataset.shape[1])
# Out:
# no. of row 215
# no. of column 15

# %% [markdown]
# #Univariate Analysis

# %%
#Distplot:-

# %%
sb.distplot(dataset["ssc_p"],hist=True, kde=True, kde_kws={'color':'Red'})
# Out:
# C:\Users\mdfai\AppData\Local\Temp\ipykernel_13456\3214092298.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset["ssc_p"],hist=True, kde=True, kde_kws={'color':'Red'})
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
#To find the histogram= frequency(repeation of data)

# %% [markdown]
# #Bivariate Analysis : Distribution Plot

# %%
#Jointplot

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset)
plt.show()

# %%
#To difine the scatter plot between ssc_p and salary.
#To show the histrogram X-axis and Y-axis

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset,kind='hex')
plt.show()

# %%
#hex= hexigon or heat map
#if more drak shows more repeation
#if less dark shows less repeation

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset,kind='kde')
plt.show()
#kde= kernel density estimation

# %%
#PairPlot

# %%
sb.pairplot(dataset,hue='gender',diag_kind="kde",kind='scatter',palette='husl')
plt.show()

# %%
#For Categorical plot: (Categorical vs Numerical)

# %%
#stripplot

# %%
sb.stripplot(x='ssc_b',y='ssc_p',data=dataset)
plt.show()

# %%
sb.stripplot(x='gender',y='ssc_p',data=dataset)
plt.show()

# %%
sb.swarmplot(x='gender',y='ssc_p',data=dataset)
plt.show()

# %%
#This function is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap.

# %%
#Violinplot

# %%
sb.violinplot(x='gender',y='ssc_p',data=dataset)
plt.show()

# %%
sb.violinplot(x='specialisation',y='salary',data=dataset,hue='gender')
plt.show()

# %%
#hue is use of differentiate (gender)

# %%
sb.boxplot(x='ssc_b',y='ssc_p',data=dataset)
plt.show()

# %%
#It is Percentile concept.

# %%
sb.boxplot(x='ssc_b',y='ssc_p',data=dataset,hue='gender')
plt.show()

# %%
#BarPlot

# %%
sb.barplot(x='ssc_b',y='ssc_p',data=dataset)
plt.show()

# %%
#Countplot

# %%
sb.countplot(x="ssc_b",data=dataset,hue='gender');
plt.show()

# %%
sb.pointplot(x = "ssc_p",y="ssc_b",data =dataset,hue='gender')
plt.show()

# %%
sb.boxplot(data = dataset, orient = "h")
plt.show()

# %%
from matplotlib import pyplot as plt
df = sb.load_dataset('exercise')
sb.catplot(x = "time", y = "pulse", hue = "kind", kind = 'violin', col = "diet", data = df);
plt.show()

# %%
df = sb.load_dataset('tips')
sb.regplot(x = "total_bill", y = "tip", data = df)
sb.lmplot(x = "total_bill", y = "tip", data = df)
plt.show()

# %%
df = sb.load_dataset('anscombe')
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"))
plt.show()

# %%
df = sb.load_dataset('anscombe')
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"),order = 2)
plt.show()

# %%
df = sb.load_dataset('tips')
g = sb.FacetGrid(df, col = "time")
g.map(plt.hist, "tip")
plt.show()

# %%
df = sb.load_dataset('iris')
g = sb.PairGrid(df)
g.map(plt.scatter);
plt.show()
